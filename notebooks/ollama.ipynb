# %%
from langchain.llms import Ollama
from mylibs.classes.AppSettings import AppSettings

settings = AppSettings()


llm = Ollama(base_url=settings.LLM_OLLAMA_URL, model=settings.LLM_OLLAMA_MODEL, temperature=0.1)
rv = llm.invoke("Wie hoch springt ein Pferd?")
print(rv)
# Out:
# Ein Pferd kann sehr hoch springen, je nach Rasse und Trainingsstand können sie bis zu 2,5 Meter oder mehr hoch springen. However, the average height of a horse's jump is around 1-2 meters (3-6 feet) high.
